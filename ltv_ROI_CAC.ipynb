# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Отлично, Виктор! Ты здорово поработал над комментариями и теперь твой проект принят.
#
# Спасибо за работу и успехов в следующих проектах!)
#
#
# ****
#
# P.S. только не забывай про описание проекта)

# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Виктор, привет!</b>
#
# Меня зовут Михаленко Дмитрий, и я буду проверять твой проект. Предлагаю общаться на «ты» :) Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Ты уже проделал большую работу над проектом, но давай сделаем его еще лучше. Ниже ты найдешь мои комментарии - **пожалуйста, не перемещай, не изменяй и не удаляй их**. Увидев у тебя ошибку, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой начальник будет поступать так же, а я пытаюсь подготовить тебя именно к работе аналитиком. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Так выделены небольшие замечания. Я надеюсь, что их ты тоже учтешь - твой проект от этого станет только лучше. Но настаивать на их отработке не буду.
#
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом.** Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# ### Загрузите данные и подготовьте их к анализу

# %% [markdown]
# Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# **Пути к файлам**
#
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Все же перед началом любого исследования должна хотя бы коротко обозначаться его основная цель и небольшое описание)

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера v 2.0 ❌:</b> Кажется, что этот комментарий остался незамеченным)

# %%
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import numpy as np

# %%
try:
    visits = pd.read_csv('D:\study\dataset\project_7/visits_info_short.csv')
    orders= pd.read_csv('D:\study\dataset\project_7orders_info_short.csv')
    costs= pd.read_csv('D:\study\dataset\project_7/costs_info_short.csv')
except:
    visits = pd.read_csv('/datasets/visits_info_short.csv')
    orders = pd.read_csv('/datasets/orders_info_short.csv')
    costs = pd.read_csv('/datasets/costs_info_short.csv')

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Воспользовались форматом try-except для чтения, универсальный способ указания пути к данным</div>

# %% [markdown]
# Изучим общую информации по DataSet

# %%
visits.head()
# Out:
#         User Id         Region   Device  Channel        Session Start  \
# 0  981449118918  United States   iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States   iPhone  organic  2019-05-01 04:46:31
# 2  590706206550  United States      Mac  organic  2019-05-01 14:09:25
# 3  326433527971  United States  Android   TipTop  2019-05-01 00:29:59
# 4  349773784594  United States      Mac  organic  2019-05-01 03:33:35
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# 2  2019-05-01 15:32:08
# 3  2019-05-01 00:54:25
# 4  2019-05-01 03:57:40

# %% [markdown]
# Структура данных в df **visits_info_short.**
# - User Id — уникальный идентификатор пользователя,
# - Region — страна пользователя,
# - Device — тип устройства пользователя,
# - Channel — идентификатор источника перехода,
# - Session Start — дата и время начала сессии,
# - Session End — дата и время окончания сессии.

# %%
orders.head()
# Out:
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# 2  529610067795  2019-05-01 11:34:04     4.99
# 3  319939546352  2019-05-01 15:34:40     4.99
# 4  366000285810  2019-05-01 13:59:51     4.99

# %% [markdown]
# Структура данных в df **orders_info_short.csv:**
# - User Id — уникальный идентификатор пользователя,
# - Event Dt — дата и время покупки,
# - Revenue — сумма заказа.

# %%
costs.head()
# Out:
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1

# %% [markdown]
# Структура данных в df **costs_info_short.csv:**
# - dt — дата проведения рекламной кампании,
# - Channel — идентификатор рекламного источника,
# - costs — расходы на эту кампанию.

# %% [markdown]
# Название столбцов в дата фреймах  выполнены не корректно , необходимо переименовать .

# %%
orders.columns=['user_id','event_dt','revenue']

# %%
visits.columns=['user_id','region','device','channel','session_start','session_end']

# %%
costs.columns=['dt','channel','costs']

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Про snake_casе не забываем</div>

# %%
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  object
#  5   session_end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %%
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Посмотрели наличие пропусков и типы данных в датасетах</div>

# %% [markdown]
# Изменим типы данных на datetime в costs['dt'], orders['Event Dt'], visits['Session Start','Session End']

# %%
costs['dt'] = pd.to_datetime(costs['dt']).dt.date
orders['event_dt']=pd.to_datetime(orders['event_dt'])
visits['session_start']=pd.to_datetime(visits['session_start'])
visits['session_end']=pd.to_datetime(visits['session_end'])

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Правильно замечено, тип object датам тут ни к чему</div>

# %% [markdown]
# **Посчитаем явные дубликаты в таблице:**

# %%
costs.duplicated().sum()
# Out:
# 0

# %%
orders.duplicated().sum()
# Out:
# 0

# %%
visits.duplicated(['user_id','session_start']).sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Наличие явных дубликатов тоже проверено</div>

# %% [markdown]
# **Поверим сумму пропусков в costs, orders, visits**

# %%
costs.isna().sum()
# Out:
# dt         0
# channel    0
# costs      0
# dtype: int64

# %%
orders.isna().sum()
# Out:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64

# %%
visits.isna().sum()
# Out:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64

# %% [markdown]
# **Выводы**
#
# Была выполнена предобработка данных:
# - Явных дубликатов не найдено.
# - Пропусков в данных не наблюдается.
# - Были изменены типы данных в столбцах в costs['dt'], orders['Event Dt'], visits['Session Start','Session End'] на datetime.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Ты провел большую работу с данными: загрузил их и провел первичный осмотр, привел столбцы к нужному формату snake_case, проанализировал наличие пропусков и дубликатов в датасете, привел время к подходящему типу данных.</div>

# %% [markdown]
# ### Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Получим функции из теории спринта</div>

# %% [markdown]
# **Добавляем функцию для создания профилей пользователей.**

# %%
def get_profiles(sessions, orders, events, ad_costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        sessions.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')
    profiles['week_day_name'] = profiles['first_ts'].dt.day_name()
    profiles['week_number'] = profiles['first_ts'].dt.isocalendar().week
    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    ad_costs = ad_costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    ad_costs['acquisition_cost'] = ad_costs['costs'] / ad_costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        ad_costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %% [markdown]
# **Добавляем функцию для подсчёта Retention Rate.**

# %%
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# **Добавляем функцию для подсчёта конверсии.**

# %%
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %% [markdown]
# **Добавляем функцию для подсчёта LTV.**

# %%
def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# **Добавляем функцию для сглаживания данных**

# %%
def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %% [markdown]
# **Добавляем функцию  для построения графика Retention Rate**

# %%
def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Добавляем функцию для построения графика конверсии**

# %%
def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Добавляем функцию для визуализации LTV и ROI**

# %%
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Необходимые функции загружены, при каждой загрузке есть заголовок, всё правильно </div>

# %% [markdown]
# ### Исследовательский анализ данных
#
# - Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.
# - Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.
# - Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.
# - Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.
#
# После каждого пункта сформулируйте выводы.

# %% [markdown]
# Найдем минимальную и максимальную даты привлечения пользователей.

# %%
min_date=costs['dt'].min()

print(f"Дата начала привлечения новых пользователей {min_date}")
# Out:
# Дата начала привлечения новых пользователей 2019-05-01

# %%
max_date=costs['dt'].max()
print(f"Дата окончания привлечения новых пользователей {max_date}")
# Out:
# Дата окончания привлечения новых пользователей 2019-10-27

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Минимальную и максимальную дату привлечения определили </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Тут для наглядности еще можно воспользоваться f строкой и вывести эти даты чуть лучше с точки зрения форматирования
#
# Вот тут можешь посмотреть, как ими можно пользоваться:
#
# * https://python-scripts.com/f-strings?ysclid=lg6j2vougc6888344

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Поправлено!.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Здорово, так стало нагляднее

# %% [markdown]
# Промо компании по привлечению новых  пользователей проводились с 1 мая 2019 по 27 октября 2019 года.

# %%
profiles = get_profiles(visits, orders,visits , costs)
profiles.head()
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month week_day_name  week_number  payer  acquisition_cost
# 0  2019-05-07 2019-05-01       Tuesday           19   True          1.088172
# 1  2019-07-09 2019-07-01       Tuesday           28  False          1.107237
# 2  2019-10-01 2019-10-01       Tuesday           40  False          0.000000
# 3  2019-08-22 2019-08-01      Thursday           34  False          0.988235
# 4  2019-10-02 2019-10-01     Wednesday           40  False          0.230769

# %% [markdown]
# Выясним, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Здесь хоть при каждом новом расчете нам не нужно будет вносить существенные изменения, но такую таблицу вполне можно завернуть в функцию, где мы по сути будем только менять region, device и channel это повысит автоматизацию кода

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Если я тебя првильно понял  то данная 👇 функция будет умесна?!.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Верно! И она поможет повысить автоматизацию

# %%
def sort (agrigator,profiles):
    table=profiles.pivot_table(
    index=agrigator, columns=['payer'], values='user_id', aggfunc='nunique')
    table.columns=['users','payers']
    table['percent']= table['payers']*100/( table['payers']+ table['users'])                                    
    return table

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Кстати, если захочешь повысить свои навыки в целом в написании кода могу посоветовать сайт
#
# * https://www.codewars.com/kata/latest/python
#
# Там, ты шаг за шагом сможешь улучшать свой скилл в python</div>

# %% [markdown]
# Выясним из каких стран пользователи приходят в приложение.

# %%
pivot_table_country=sort('region',profiles)

# %%
pivot_table_country.sort_values(by='percent', ascending=False)
# Out:
#                users  payers   percent
# region
# United States  93100    6902  6.901862
# Germany        14365     616  4.111875
# UK             16875     700  3.982930
# France         16787     663  3.799427

# %% [markdown]
# **Вывод:**
# Пользователи из США являются наиболее активными в приложении Procrastinate Pro+ и более склонны к становлению платящими пользователями. Коэффициент конверсии для пользователей из Америки самый высокий и составляет 6,9%.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Когда считается доля ведь не совсем корректно делить true на false, мы ведь ищем долю среди всех посетителей, а не отношение платящих к неплатящим.
#
# Если на пальцах: есть 2 апельсина и 3 лимона, нужно определить долю апельсинов среди цитрусовых. Нужно ведь разделить 2 на 5, а не на 3.
#
# Не буду указывать это замечание несколько раз, чтобы не повторяться, но оно актуально для всех расчетов доли на третьем шаге)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Поправлено!👍 Везде во всех расчетах. Не правильно понял задание 😓. (Если на пальцах: есть 2 апельсина и 3 лимона, нужно определить долю апельсинов среди цитрусовых. Нужно ведь разделить 2 на 5) - Логично </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Также абсолютно корректно указан новый расчет, сейчас все как надо

# %% [markdown]
# Выясним какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи.

# %%
pivot_table_device= sort ('device',profiles)

# %%
pivot_table_device.sort_values(by='percent', ascending=False)
# Out:
#          users  payers   percent
# device
# Mac      28130    1912  6.364423
# iPhone   51097    3382  6.207897
# Android  32982    2050  5.851793
# PC       28918    1537  5.046790

# %% [markdown]
# **Выводы**
# 1.	iPhone - наиболее популярная платформа среди пользователей приложения Procrastinate Pro+.
# 2.	Использование приложения на платформах Android, PC и Mac менее распространено.
# 3.	На платформах Mac и iPhone наблюдается самая высокая конверсия в платежи, а на PC - самая низкая.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Соответственно, тут расчеты также нужно поправить

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Поправлено!👍

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Да, все здорово

# %% [markdown]
# Изучим рекламные источники привлечения

# %%
pivot_table_channel= sort ('channel',profiles)

# %%
pivot_table_channel.sort_values(by='percent', ascending=False)
# Out:
#                     users  payers    percent
# channel
# FaceBoom            25587    3557  12.204914
# AdNonSense           3440     440  11.340206
# lambdaMediaAds       1924     225  10.469986
# TipTop              17683    1878   9.600736
# RocketSuperAds       4096     352   7.913669
# WahooNetBanner       8100     453   5.296387
# YRabbit              4147     165   3.826531
# MediaTornado         4208     156   3.574702
# LeapBob              8291     262   3.063253
# OppleCreativeMedia   8372     233   2.707728
# organic             55279    1160   2.055316

# %% [markdown]
# **Вывод:**  Основными рекламными источниками привлечения пользователей являются каналы FaceBoom и TipTop. Всего было привлечено 25,587 пользователей по каналу FaceBoom и 17,683 пользователей по каналу TipTop. Наибольшая конверсия наблюдается среди пользователей, пришедших по каналу FaceBoom. Критично малая конверсия наблюдается в источнике привлечения  organic

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> В остальном очень наглядно все отображаешь, молодец </div>

# %% [markdown]
# **Общие выводы**
# Промо-кампания по привлечению новых пользователей проводилась в течение периода с 1 мая 2019 года по 27 октября 2019 года. Это указывает на конкретный временной фрейм, в котором были сосредоточены маркетинговые усилия для привлечения пользователей.
#
# - Анализ показывает, что пользователи из США проявляют наибольшую активность в приложении Procrastinate Pro+ и обладают наиболее высоким коэффициентом конверсии в платящих пользователей, составляющим 6,9%. Это означает, что пользователи из США имеют большую склонность становиться платежеспособными клиентами. Следовательно, стоит продолжать акцентировать внимание на привлечение и удержание пользователей из этой страны.
#
# - Платформа iPhone является наиболее популярной среди пользователей приложения Procrastinate Pro+. Отмечается, что конверсия в платежи на платформах Mac и iPhone выше, чем на платформе PC, а использование приложения на платформах Android, PC и Mac менее распространено. Эта информация позволяет сделать вывод о необходимости уделить особое внимание разработке и оптимизации приложения для платформ Mac и iPhone, чтобы продолжить повышение конверсии в платежи.
#
# - Исследование также выявило, что основными рекламными источниками привлечения пользователей являются каналы FaceBoom и TipTop. Канал FaceBoom показал наибольшую эффективность среди всех источников привлечения, обеспечив привлечение 25 587 пользователей, а канал TipTop также демонстрировал хорошие результаты, привлекая 17 683 пользователей. Однако, органический источник привлечения показал критически низкую конверсию. Эти выводы указывают на важность усиления маркетинговых усилий в каналах FaceBoom и TipTop и на необходимость пересмотра и оптимизации стратегии привлечения через органический источник.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> И здесь сами выводы тоже нужно будет немного поправить, ну сама суть на самом деле останется почти без изменений

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> И выводы теперь тоже немного доработаны с учетом новых расчетов

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Поправлено!👍

# %% [markdown]
# ### Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %% [markdown]
# Рассчитаем общую сумму потраченную на маркетинг.

# %%
price=int(costs['costs'].sum())

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Определили общую сумму трат </div>

# %%
print(f"Общая сумма, потраченная на маркетинг, равняется {price}")
# Out:
# Общая сумма, потраченная на маркетинг, равняется 105497

# %% [markdown]
# Выясниvм, как траты распределены по рекламным источникам.

# %%
money_for_channel= profiles.pivot_table(
    index='channel', values='acquisition_cost', aggfunc='sum'
)

# %%
money_for_channel['percent_of_total']=money_for_channel['acquisition_cost']*100/(money_for_channel['acquisition_cost'].sum())

# %%
money_for_channel.sort_values(by='acquisition_cost',ascending=False)
# Out:
#                     acquisition_cost  percent_of_total
# channel
# TipTop                      54751.30         51.898295
# FaceBoom                    32445.60         30.754910
# WahooNetBanner               5151.00          4.882589
# AdNonSense                   3911.25          3.707441
# OppleCreativeMedia           2151.25          2.039152
# RocketSuperAds               1833.00          1.737485
# LeapBob                      1797.60          1.703930
# lambdaMediaAds               1557.60          1.476436
# MediaTornado                  954.48          0.904744
# YRabbit                       944.22          0.895018
# organic                         0.00          0.000000

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Для наглядности еще можно отобразить проценты от общих трат)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Поправлено!✌️

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Так отличие двух каналов стало еще нагляднее

# %% [markdown]
# Наибольшие по траты на привлечения новых пользователей  пришлись на  источники TipTop, FaceBoom, WahooNetBanner

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> По самим выводам все корректно</div>

# %%
pivot_for_month=profiles.pivot_table(index='month',columns=['channel'], values='acquisition_cost', aggfunc='sum')

# %%
pivot_for_week=profiles.pivot_table(index='week_number',columns=['channel'], values='acquisition_cost', aggfunc='sum')

# %%
pivot_for_weeek_name=profiles.pivot_table(index='week_day_name',columns=['channel'], values='acquisition_cost', aggfunc='sum')

# %%
ax1 = plt.subplot(2, 2, 1)
pivot_for_month.plot(figsize=(20,20),grid=True, ax=ax1)
plt.legend()
plt.xlabel('Месяци')
plt.title('Расходы на привлечение По месяцам')

    
ax2 = plt.subplot(2, 2, 2, sharey=ax1)
pivot_for_week.plot(grid=True, ax=ax2)
plt.xlabel('Номера недель')
plt.title('Расходы на привлечение по неделям')

ax3 = plt.subplot(2, 2, 3, sharey=ax1)
pivot_for_weeek_name.plot(grid=True, ax=ax3)
plt.xlabel('Дни недели')
plt.title('Расходы на привлечение но дням недели')

plt.show()

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Не совсем верно. По заданию тут просили:
#
# * Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
#
# То есть тут по заданию все же нужно было построить два графика: по месяцам и по неделям, а сейчас отображен только график по дням

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Есть вопрос разве график с window=7  filter_data(df, window) не будет эквивалентен недельному графику ?❓❓❓

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Не совсем, ведь временное окно будет перемещаться по всем значениям и брать соответственно среднее по каждой точке на основании 7 дней, а обычный график по неделям ничего не сглаживает, он просто берет само значение

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Поправлено!✌️

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Правильно!

# %% [markdown]
# Расходы на привлечения имеют динамику возрастать только для двух каналов TipTop в пять раз от превоначальных трат, FaceBoom в 2 раза от первоночальных трат

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Но по описанию верно, на TipTop и FaceBoom было затрачено существенно больше средств, чем на все другие каналы</div>

# %% [markdown]
# Узнаем сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.

# %%
pivot_cac=profiles.pivot_table(
    index='channel',  values='acquisition_cost', aggfunc='mean'
)

# %%
pivot_cac.columns=['CAC']

# %%
pivot_cac.sort_values(by='CAC',ascending=False)
# Out:
#                          CAC
# channel
# TipTop              2.799003
# FaceBoom            1.113286
# AdNonSense          1.008054
# lambdaMediaAds      0.724802
# WahooNetBanner      0.602245
# RocketSuperAds      0.412095
# OppleCreativeMedia  0.250000
# YRabbit             0.218975
# MediaTornado        0.218717
# LeapBob             0.210172
# organic             0.000000

# %%
filter_data(profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
),7).plot(grid=True, figsize=(15, 15))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Молодец, что тут кроме самих расчетов средних по САс еще добавил значения САС для каждого канала в динамике </div>

# %% [markdown]
# 1.	Канал TipTop имеет самую высокую среднюю стоимость привлечения пользователя (CAC), в то время как каналы LeapBob, MediaTornado, YRabbit и OppleCreativeMedia имеют наименьший CAC.
# 2.	CAC для канала TipTop вырос в 3,5 раза за период наблюдений, в то время как CAC для остальных каналов остается неизменным. Это может указывать на стабильность их эффективности в привлечении новых пользователей

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Всё правильно и в итоге самый дорогой канал в абсолютном отношении у нас стал самым дорогим в стоимости привлечения пользователей</div>

# %% [markdown]
# **Выводы**
#
# 1. Общие затраты на маркетинг составляют 105497.
# 2. Наибольшие расходы на привлечение новых пользователей пришлись на источники TipTop, FaceBoom и WahooNetBanner. Это указывает на их значительную роль в привлечении аудитории.
# 3. Расходы на привлечение имеют динамику возрастания только для двух каналов: TipTop увеличился в 5 раз по сравнению с первоначальными тратами, а FaceBoom увеличился в 2 раза. Этот рост может быть связан с растущими стоимостями рекламы или изменениями в стратегии маркетинга этих каналов.
# 4. Канал TipTop имеет самую высокую среднюю стоимость привлечения пользователя (CAC), что может указывать на его более высокую стоимость в сравнении с другими каналами.
# 5. CAC для канала TipTop вырос в 3,5 раза за период наблюдений, в то время как CAC для остальных каналов остается неизменным. Это может свидетельствовать о нестабильности и возможной неэффективности стратегии привлечения через канал TipTop, в то время как остальные каналы демонстрируют более стабильные результаты.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Промежуточный вывод тоже указан отлично и самыми заметными каналами по тратам у нас стали TipTop и FaceBoom, теперь интересно что с их остальными бизнес-показателями</div>

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Но здесь согласно логике проекта - следует провести фильтрацию органических пользователей, ведь мы анализируем расходы на рекламу, а органика нам ничего не стоила.
#
# Обрати, пожалуйста внимание на то, что после удаления органики часть графиков может несколько изменится и нужно будет скорректировать выводы

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> ☝️ Поправлено! 😃 . Для себя было интересно сравнивать organicov  и всех остальных. Сейчас понял что это грубейшая ошибка.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Органику убрали

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> А вот дата и горизонт указаны, тут все классно</div>

# %%
observation_date=datetime(2019, 11, 1).date()

# %%
horizon_days=14

# %% [markdown]
# Для продолжения исследования  удалим Organic пользователей из таблиц.

# %%
 visits=visits[visits['channel']!='organic']

# %%
profiles=profiles[profiles['channel']!='organic']

# %% [markdown]
# #### Проанализируем конверсию пользователей в зависимости от канала привлечения, типа устройства пользователя и страны пользователя

# %% [markdown]
# ##### Конверсия пользователей в зависимости от типа устройства

# %%
conversion_raw, conversion, conversion_history= get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=['device'],
    ignore_horizon=False,
)

# %%
plot_conversion(conversion, conversion_history, horizon_days, window=30)

# %% [markdown]
#  **Вывод** При анализе конверсии пользователей в зависимости от типа устройства можно установить, что самая высокая конверсия наблюдается у пользователей на платформах Mac и iPhone. В то же время, на 14-й день после установки приложения наблюдается падение конверсии у пользователей на платформе PC с июля. Остальные платформы, такие как Android и Mac, демонстрируют стабильный рост конверсии. Эти результаты указывают на важность оптимизации приложения для пользователей на платформе PC, чтобы снизить падение конверсии и увеличить общую эффективность маркетинговых усилий.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Да, и Apple как мы уже видели здорово конвертируется

# %% [markdown]
# ##### Конверсия пользователей в зависимости от страны пользователя

# %%
conversion_raw, conversion, conversion_history= get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=['region'],
    ignore_horizon=False,
)

# %%
plot_conversion(conversion, conversion_history, horizon_days, window=30)

# %% [markdown]
#  **Вывод** При сравнении конверсии пользователей в разных странах выявляется, что в США коэффициент конверсии значительно выше, чем в Германии, Франции и Великобритании. Интересно отметить, что в США наблюдается динамика роста конверсии пользователей на 14-й день в июне. В то же время, в остальных странах конверсия пользователей на 14-й день остается стабильной. Эти результаты подчеркивают важность ориентирования маркетинговых усилий на американский рынок и использование специфических стратегий для удержания пользователей в других странах.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> А в странах лидер конверсии еще более явный, при этом и динамика у него выделяется

# %% [markdown]
# ##### Конверсия пользователей в зависимости от канала привлечения

# %%
conversion_raw, conversion, conversion_history= get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=['channel'],
    ignore_horizon=False,
)

# %%
plot_conversion(conversion, conversion_history, horizon_days, window=30)

# %% [markdown]
# **Вывод** Анализ конверсии пользователей по каналам привлечения показывает, что каналы FaceBoom, AdNonSense, lambdaMediaAds и TipTop имеют наиболее высокую конверсию. Это указывает на эффективность этих каналов в привлечении пользователей и их превращении в платящих клиентов. Рекомендуется уделять особое внимание и продолжать инвестировать в эти каналы для дальнейшего увеличения конверсии и максимизации результатов маркетинговых кампаний.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> В целом, все хорошо, вот только промежуточные рекомендации нам давать пожалуй рано, поскольку конверсия не является единственным и главным показателем, по которому мы ориентируемся, это лишь один из показателей</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Тут выводы скрыли

# %% [markdown]
# #### Проанализируем удержанием пользователей в зависимости от канала привлечения, типа устройства пользователя и страны пользователя.

# %% [markdown]
# ##### Удержанием пользователей в зависимости от канала привлечения

# %%
retention_raw, retention, retention_history=get_retention(profiles,visits,observation_date,horizon_days,dimensions=['channel'])

# %%
plot_retention(retention, retention_history, horizon_days, window=30)

# %% [markdown]
# **Выводы**
# 1. Низкий коэффициент удержания наблюдается для каналов FaceBoom и AdNonSense. В то же время, другие каналы показывают более высокий коэффициент удержания. Это указывает на необходимость пересмотра и оптимизации стратегий удержания в рамках этих конкретных каналов, чтобы улучшить удержание пользователей и повысить их долгосрочную активность в приложении
# 2. Динамика удержания на канале TipTop крайне не стабильна . FaceBoom показывает низкие но стабильные результаты удержания пользователей.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Также правильно и лидеры конверсии в каналах плохо удерживаются

# %% [markdown]
# ##### Удержанием пользователей в зависимости от типа устройства

# %%
retention_raw, retention, retention_history=get_retention(profiles,visits,observation_date,horizon_days,dimensions=['device'])

# %%
plot_retention(retention, retention_history, horizon_days, window=30)

# %% [markdown]
# **Выводы**
# Пользователи PC демонстрируют самый высокий коэффициент удержания. Однако, стоит отметить, что на 14-й день после установки приложения наблюдается падение удержания у пользователей PC в июне. Это может требовать дополнительного исследования и оптимизации для улучшения удержания пользователей на платформе PC в этот период.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Молодец! И PC оказывается у нас был лидером в удержании

# %% [markdown]
# ##### Удержанием пользователей в зависимости от страна пользователя

# %%
retention_raw, retention, retention_history=get_retention(profiles,visits,observation_date,horizon_days,dimensions=['region'])

# %%
plot_retention(retention, retention_history, horizon_days, window=30)

# %% [markdown]
# **Выводы**
# 1. В США динамика удержания пользователей стабильная, но низкая, в отличие от Франции, Германии и Англии, где наблюдается нестабильность из-за интервального проведения рекламных кампаний.
#
# 2. В США отмечается самый низкий коэффициент удержания среди платящих пользователей.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> А тут в очередной раз видим, что лидеры конверсии имеют низкую лояльность

# %% [markdown]
# ##### Удержанием пользователей

# %%
retention_raw, retention, retention_history=get_retention(profiles,visits,observation_date,horizon_days,dimensions=[])

# %%
plot_retention(retention, retention_history, horizon_days, window=30)

# %% [markdown]
# **Выводы**
# 1. Анализ показывает общую тенденцию падения удержания платящих пользователей с июня по август, с некоторым восстановлением в сентябре и последующим падением в октябре. Это может указывать на необходимость усиления усилий по удержанию пользователей и оптимизации стратегий удержания во временные периоды, когда наблюдается снижение удержания.
#
# 2. Важно отметить, что в США наблюдается самый низкий коэффициент удержания среди платящих пользователей. Это может свидетельствовать о необходимости углубленного изучения американского рынка, выявления причин низкого удержания и применения специфических стратегий для удержания пользователей в этой стране.
#
# 3. При анализе удержания пользователей в зависимости от типа устройства можно заметить, что пользователи PC демонстрируют самый высокий коэффициент удержания. Однако, стоит отметить, что на 14-й день после установки приложения наблюдается падение удержания у пользователей PC в июне. Это может требовать дополнительного исследования и оптимизации для улучшения удержания пользователей на платформе PC в этот период.
#
# 4. Касательно удержания пользователей в зависимости от канала привлечения, низкий коэффициент удержания наблюдается для каналов FaceBoom и AdNonSense. В то же время, другие каналы показывают более высокий коэффициент удержания. Это указывает на необходимость пересмотра и оптимизации стратегий удержания в рамках этих конкретных каналов, чтобы улучшить удержание пользователей и повысить их долгосрочную активность в приложении.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> По удержанию тоже в целом все по делу и замечены основные особенности как по сегментам, так и по динамике, но конец промежуточного вывода тут к сожалению обрывается</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> И концовку вывода доработал, очень хорошо

# %% [markdown]
# #### Анализ окупаемости рекламы

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,orders,observation_date,horizon_days,dimensions=[])

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days, window=7)

# %% [markdown]
# **Выводы**
# 1. Рекламная компания не принесла достаточного дохода, не окупилась.
# 2. Динамика ROI на протяжении исследуемого периода (июнь и июль) опустилась ниже порога окупаемости. Хотя наблюдалось небольшое восстановление в июле, она снова опустилась ниже порога окупаемости, и не удалось его преодолеть.
# 3. В июне 2019 года динамика стоимости привлечения резко возросла.
# 4. Динамика LTV (пожизненной ценности) пользователей на 14-й день крайне нестабильна.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Здесь и далее хорошо строишь необходимые согласно ТЗ графики, но все же пользователю достаточно сложно получить информацию из подряд идущих бизнес-метрик и чтобы обратить к выводам ему нужно будет пролистывать каждый раз 20 графиков, смотреть на выводы и возвращаться назад. Тут стоит немного разделить исследование и по каждой группе графиков писать отдельные промежуточные выводы.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> ☝️ Поправлено! 😃 . Стало удобнее.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Все пункты и правда здорово отмечены, САС растет, LTV хоть и условно стабильно, но для положительного ROI кампании его мало, динамика ROI ухудшается</div>

# %% [markdown]
# ##### Анализ окупаемости рекламы в зависимости от устройства

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,orders,observation_date,horizon_days,dimensions=['device'])

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days, window=30)

# %% [markdown]
# **Вывод**
# 1. Окупаемость пользователей различных платформ: пользователи PC окупаются в среднем на 7-й день, пользователи Android - на 11-й день, а пользователи iPhone и Mac не окупаются до 14-го дня.
#
# 2. Рост стоимости привлечения пользователей: стоимость привлечения пользователей iPhone и Mac значительно возрастает, в то время как привлечение пользователей PC и Android увеличивается, но не так существенно.
#
# 3. Динамика ROI для всех платформ: начиная с июня, в июле снижаясь ниже порога окупаемости и  более не востанавливаясь. ROI пользователей PC остается положительным, однако имеет тенденцию к снижению.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Успешной с точки зрения окупаемости можно назвать лишь PC, но это устройство дешевле всего стоит, при этом самые дорогие устройства Apple окупаются хуже всего, но динамика окупаемости выглядит плохо вообще везде</div>

# %% [markdown]
# ##### Анализ окупаемости рекламы в зависимости от страны пользователя

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,orders,observation_date,horizon_days,dimensions=['region'])

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days, window=30)

# %% [markdown]
# **Вывод:**
# 1. LTV (пожизненная ценность) пользователей в США значительно выше, чем в Англии, Германии и Франции. LTV в Англии, Германии и Франции находится на одном уровне.
#
# 2. Динамика стоимости привлечения пользователей из США резко возрастает с июня. В то же время, стоимость привлечения в Англии, Германии и Франции остается постоянной.
#
# 3. Пользователи из Англии, Германии и Франции окупаются в среднем на 3-й день, в то время как пользователи из США не окупаются вовсе.
#
# 4. ROI (отношение прибыли к затратам) пользователей на 14-й день в Англии, Германии и Франции нестабильны, но всегда находятся выше линии окупаемости. В июле пользователи из США оказываются ниже линии окупаемости и не восстанавливаются впоследствии.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Все корректно, высокое LTV, высокий САС, низкая окупаемость у США, при этом другие страны окупаются достаточно хорошо. Тут было бы интересно, какая у нас разбивка в привязках страна-устройство-канал, то есть чтобы определить проблему США более точечно нам это было бы полезно знать)</div>

# %% [markdown]
# ##### Анализ окупаемости рекламы в зависимости от канала привлечения

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,orders,observation_date,horizon_days,dimensions=['channel'])

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days, window=30)

# %% [markdown]
# **Выводы**
# 1. LTV пользователей на каналах TipTop и 'lambdaMediaAds' является самым высоким среди остальных каналов привлечения.
#
# 2. Пользователи, привлеченные через каналы AdNonSense, TipTop и FaceBoom, не окупились. Однако пользователи, пришедшие через каналы 'WahooNetBanner' и OppleCreativeMedia, окупились на 5-6 день, а пользователи, пришедшие через каналы 'OppleCreativeMedia', YRabbit, MediaTornado, lambdaMediaAdsRocketSuperAds и LeapBob, окупились на 3-4 день.
#
# 3. Стоимость привлечения новых пользователей на канале TipTop выросла в 4 раза с июня месяца.
#
# 4. ROI (отношение прибыли к затратам) на каналах AdNonSense, TipTop и FaceBoom всегда находился ниже порога окупаемости.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Основные проблемы по бизнес-показателям хорошо определены: дорогие сегменты окупаются в кампании хуже всего, при этом и динамика у них выглядит достаточно негативно, стоимость привлечения в отдельных срезах существенно увеличивается</div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Но ведь здесь еще важно подробнее описать и те сегменты, которые смогли достичь "хороших" показателей, поскольку дальше нам нужно будет дать рекомендации менеджерам

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> ☝️ Поправлено!  😃 .

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> И положительные моменты для каналов тоже доработали

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера ⚠️:</b> Еще исходя из общих проблем Штатов было бы интересно посмотреть например на бизнес-показатели (графики) в разрезе США-Европа или еще как вариант попробовать посмотреть на общие показатели без лидеров по САС в кампании

# %% [markdown]
# ### Дополнительные иследования.

# %% [markdown]
# Исключим не эффективные  каналы привлечения AdNonSense, TipTop, FaceBoom из наших данных для поиска эффективных каналов рекламных  акций.

# %%
values = ['AdNonSense', 'TipTop', 'FaceBoom']

# %%
profiles=profiles[profiles['channel'].isin(values)==False]

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,orders,observation_date,horizon_days,dimensions=['region'])

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days, window=30)

# %% [markdown]
# **Выводы:**
#
# После исключения каналов AdNonSense, TipTop и FaceBoom ситуация изменилась:
#
# - Пользователи из США стали окупаться на 2-й день, что говорит о повышении эффективности привлечения в данной стране.
#
# - Стоимость привлечения пользователей из США начала снижаться с июля, что указывает на оптимизацию затрат и эффективное использование рекламных ресурсов.
#
# - Динамика ROI на 14-й день у пользователей из США значительно превышает ROI пользователей из Англии, Германии и Франции. Это говорит о более высокой прибыльности и успешности привлечения пользователей в США.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Здорово! И оказывается проблемы кампании были исключительно в каналах

# %%
ltv_raw, ltv, ltv_history, roi, roi_history = get_ltv(profiles,orders,observation_date,horizon_days,dimensions=['device'])

# %%
plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon_days, window=30)

# %% [markdown]
# **Вывподы:**
#
# После исключения каналов AdNonSense, TipTop и FaceBoom ситуация изменилась:
#
# 1. Пользователи Mac и iPhone стали окупаться на 2-й день, что свидетельствует о повышении эффективности привлечения их в приложение.
#
# 2. Стоимость привлечения пользователей Mac и iPhone больше не увеличивается, что говорит о стабилизации затрат на их привлечение.
#
# 3. Динамика ROI на 14-й день пользователей всех платформ остается стабильно выше линии окупаемости. Это указывает на успешность монетизации и прибыльности привлеченных пользователей в долгосрочной перспективе.
# 4. LTV и ROI пользователей PC постепенно снижается.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> По устройствам также заметно влияние каналов, без дорогих каналов Apple выглядит весьма прилчино

# %%
pivot_table_device= sort ('device',profiles)

# %%
pivot_table_device.sort_values(by='percent', ascending=False)
# Out:
#          users  payers   percent
# device
# Android  10497     471  4.294311
# PC       12028     542  4.311854
# iPhone   10724     524  4.658606
# Mac       5889     309  4.985479

# %%
pivot_table_channel= sort ('channel',profiles)

# %%
pivot_table_channel.sort_values(by='percent', ascending=False)
# Out:
#                     users  payers    percent
# channel
# lambdaMediaAds       1924     225  10.469986
# RocketSuperAds       4096     352   7.913669
# WahooNetBanner       8100     453   5.296387
# YRabbit              4147     165   3.826531
# MediaTornado         4208     156   3.574702
# LeapBob              8291     262   3.063253
# OppleCreativeMedia   8372     233   2.707728

# %%
pivot_table_region= sort ('region',profiles)

# %%
pivot_table_region.sort_values(by='percent', ascending=False)
# Out:
#                users  payers   percent
# region
# United States  12451     673  5.128010
# UK              9438     421  4.270210
# Germany         7961     348  4.188230
# France          9288     404  4.168386

# %% [markdown]
# ### Напишите выводы
#
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# **Выводы:**
# Анализ ситуации указывает на несколько проблем, с которыми сталкивается промо-кампания по привлечению новых пользователей для приложения Procrastinate Pro+:
#
# 1. Рекламная компания столкнулась с неудачей из-за трех каналов AdNonSense, TipTop и FaceBoom, несмотря на их высокую конверсию. Однако, эти каналы не принесли ожидаемой окупаемости и ROI, а затраты на привлечение пользователей в них постепенно возрастали. Необходимо провести анализ этих каналов, оптимизировать рекламные затраты и улучшить окупаемость компании.
#
# 2. Общая динамика пожизненной стоимости клиента (LTV) нестабильна, что указывает на проблемы с удержанием пользователей и их монетизацией. Для улучшения LTV необходимо сосредоточиться на улучшении пользовательского опыта, функциональности приложения и предложений, чтобы повысить удержание пользователей и максимизировать их стоимость.
#
# 3. Возникли проблемы с монетизацией пользователей из США, несмотря на их высокую конверсию и количество. Рекламная кампания не окупилась из-за значительного увеличения стоимости привлечения новых пользователей в течение периода проведения рекламной акции. Кроме того, уровень удержания пользователей из США ниже, чем у других стран. Рекомендуется провести анализ причин высокой стоимости привлечения и разработать стратегию удержания пользователей из США для улучшения окупаемости рекламной кампании.
# 4. Каналы 'OppleCreativeMedia', YRabbit, MediaTornado, lambdaMediaAds RocketSuperAds, LeapBob показали очень высокие результаты в ROI, что свидетельствует о их эффективности в привлечении и удержании пользователей. Рекомендуется увеличить бюджет и ресурсы для этих каналов, чтобы масштабировать их деятельность и привлечь больше качественных пользователей. Также следует провести анализ успешных элементов и стратегий этих каналов и применить их в других каналах привлечения, чтобы повысить их эффективность и ROI.
# 5. Падение LTV и ROI у пользователей на ПК: Наблюдается заметное снижение LTV и ROI у пользователей, которые используют приложение на компьютере начиная с июля месяца. Вероятные причины включают недостаточную оптимизацию приложения под эту платформу, возможные проблемы с функциональностью или неудобный интерфейс. Рекомендуется провести детальный анализ и исправить эти проблемы, сфокусировавшись на улучшении пользовательского опыта и повышении конверсии для пользователей на ПК."

# %% [markdown]
# **Рекомендации:**
# 1. Рекомендуется прекратить использование каналов AdNonSense, TipTop и FaceBoom, которые не приносят ожидаемой окупаемости. Вместо этого, исследуйте другие каналы привлечения с более высокими показателями ROI и LTV. Проведите подробный анализ каналов чтобы выявить причины их низкой окупаемости. Возможно, требуется пересмотреть их таргетинговые параметры, контент или бюджеты, а также проверить соответствие вашей целевой аудитории.
#
# 2. Проведите анализ успешных каналов, таких как 'OppleCreativeMedia', YRabbit, MediaTornado, lambdaMediaAds RocketSuperAds и LeapBob, чтобы выявить ключевые элементы и стратегии, способствующие их успеху. Примените эти наработки к другим каналам привлечения для увеличения их эффективности и ROI.
#
# 3. Сосредоточьтесь на оптимизации приложения и предложений для пользователей на ПК. Проведите анализ и исправьте возможные проблемы с функциональностью, удобством использования и интерфейсом приложения на компьютере. Улучшение пользовательского опыта на ПК поможет повысить конверсию и окупаемость этой платформы.
#
# 4. Уделите внимание улучшению удержания пользователей и максимизации их LTV. Разработайте стратегии для улучшения пользовательского опыта, предоставления ценных предложений и поощрений, которые помогут удерживать пользователей долгое время и повысить их стоимость для компании.
#
# 5. Регулярно отслеживайте показатели ROI, LTV и стоимости привлечения для всех каналов привлечения и пользовательских групп. Это поможет идентифицировать проблемные области, принять меры по их исправлению и оптимизировать рекламные затраты для достижения более высокой окупаемости.

# %% [markdown]
# <div class="alert alert-danger">
# <b>Комментарий ревьюера ❌:</b> Но рекомендации и выводы менеджерам стоит дополнить и доработать:
#
# * "*Падение конверсии у пользователей на ПК: Существует заметное падение конверсии у пользователей на компьютерах с июля месяца. Это может быть вызвано недостаточной оптимизацией приложения под эту платформу, возможными проблемами функциональности или неудобным интерфейсом. Необходимо провести анализ и исправить эти проблемы, чтобы повысить конверсию пользователей на ПК*"
#
# и
#
# * "*Стоимость привлечения пользователей на платформах iPhone и Mac: Пользователи на платформах iPhone и Mac демонстрируют высокую конверсию, однако стоимость привлечения новых пользователей на этих платформах постоянно растет. Это приводит к невыгодности рекламной компании на данных платформах. Необходимо исследовать причины роста стоимости привлечения и найти способы снизить затраты, чтобы обеспечить окупаемость рекламы на платформах iPhone и Mac.*"
#
# На самом деле, вполне возможно в самих устройствах у нас и нет каких-то существенных проблем, здесь стоит посмотреть как выглядят показатели устройств, если исключить дорогие каналы привлечения, может быть показатели не испытывают каких-то заметных сложностей. Соответственно, после этого можно будет доработать рекомендации;
#
# *****
#
# * "*Оптимизировать рекламные затраты и анализировать эффективность каналов привлечения, особенно FaceBoom и TipTop.*" - верное предложение, но стоит акцентировать внимание на какие именно каналы нам стоит распределить оптимизированный бюджет и какие каналы стали наиболее успешными и перспективными. Также, кроме этих двух каналов у нас был еще один неокупившийся канал;
#
# *****

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> ☝️ Поправлено! . Выводы претерпели сильную переработку. Интересно твое мнение.:	😅

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера v 2.0 ✔️:</b> Тут тоже все как надо, особенно помогла детализация выводов в последнем разделе и окончание раздела, где мы проверили дополинтельную разбивку и как выглядела кампания без дорогих каналов, это поможет менеджерам сделать правильные решения в будущем

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Рекомендации:
#
# По сути своей весь анализ в этом спринте в той или иной мере основан на когортном анализе, прикреплю полезные ссылки на него. Но на самом деле очень советую в целом полистать gopractice, там очень хорошо описаны все бизнесовые и продуктовые метрики, этот курс часто приводят в пример для продуктовых аналитиков.
#
# https://blog.ohmystats.com/cohort-analysis/
#
# https://gopractice.ru/cohort_analysis/
#
# https://smysl.io/blog/pandas-cohorts/</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера ✔️:</b> Виктор, проект отличный! У тебя очень сильные аналитические навыки, владение инструментами для проведения исследования и навыки продуктовой аналитики. Но всё же у меня есть несколько замечаний и я попрошу тебя исправить их, чтобы проект стал еще лучше! </div>
